# %% [markdown]
# ## Importing

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from mpl_toolkits.mplot3d import Axes3D
import warnings
warnings.filterwarnings("ignore", module="matplotlib")
from sklearn.metrics import silhouette_score

from scipy.cluster.hierarchy import linkage, dendrogram
from scipy.cluster.hierarchy import fcluster
from sklearn.manifold import TSNE
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# ## Examing

# %%
df = pd.read_csv("https://raw.githubusercontent.com/wojo501/clusteringML/main/data/bank-full.csv")
df.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  unknown    5   may       261         1     -1         0  unknown  no
# 1  unknown    5   may       151         1     -1         0  unknown  no
# 2  unknown    5   may        76         1     -1         0  unknown  no
# 3  unknown    5   may        92         1     -1         0  unknown  no
# 4  unknown    5   may       198         1     -1         0  unknown  no

# %%
ratio = len(df[df["y"] == "yes"]) / len(df)
ratio
# Out:
# 0.11698480458295547

# %%
df.shape
# Out:
# (45211, 17)

# %%
has_null = df.isnull().any().any()
has_null
# Out:
# False

# %%
corr = df.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(corr, annot=True, fmt=".2f", linewidths=.5, cmap='RdYlBu_r')
plt.show()

# %%
df_train, df_test = train_test_split(df, test_size=0.3, shuffle=True)
# Reset indexes for df_train
df_train.reset_index(drop=True, inplace=True)
df_test.reset_index(drop=True, inplace=True)

# %%
def idx_range(df):
    index_min = df.index.min()
    index_max = df.index.max()

    print(f"Index range: {index_min} - {index_max}")

# %%
df_train.shape
# Out:
# (31647, 17)

# %% [markdown]
# ## Business case
#
# Telephonic campaign of a Portuguese bank. Objective: offering term deposits. 11% positive responses.
# Information from the dataset (17 columns, 45211 rows):
#
# - Age
# - Occupation
# - Education
# - Marital status
# - Duration of phone calls
# - Indebtedness
# - Contact method
# - ...
#
# <p style="color: red;"> Our approach: To group clients using clustering and deceide which atributes are most meaningfull for each group. </p>

# %% [markdown]
# ## Transformers

# %%
def encode_categorical(df_orginal, reverse=False):
    df = df_orginal.copy(deep=True)
    
    months = ['jan', 'feb', 'mar', 'apr', 'may', 'jun', 'jul', 'aug', 'sep', 'oct', 'nov', 'dec']
    month_num = {months[i]: i+1 for i in range(len(months))}
    month_num_reverse = {i+1: months[i] for i in range(len(months))}
    
    edu_num = {'tertiary':2, 'secondary':1, 'unknown':-1, 'primary':0}
    edu_num_reverse = {v: k for k, v in edu_num.items()}
    
    marital_num = {'single':0, 'married':1, 'divorced':2}
    marital_num_reverse = {v: k for k, v in marital_num.items()}
    
    # Encoding for binary columns
    binary_num = {"no":0 ,"yes":1}
    binary_num_reverse = {v: k for k, v in binary_num.items()}
    
    binaries = [col for col in df.columns if set(df[col].unique()) in [{"yes", "no"}, {0, 1}]]

    if reverse:
        df["month"] = df["month"].map(month_num_reverse)
        df["education"] = df["education"].map(edu_num_reverse)
        df["marital"] = df["marital"].map(marital_num_reverse)
        df[binaries] = df[binaries].apply(lambda x: x.map(binary_num_reverse))
        
    else:
        df["month"] = df["month"].map(month_num)
        df["education"] = df["education"].map(edu_num)
        df["marital"] = df["marital"].map(marital_num)
        df[binaries] = df[binaries].apply(lambda x: x.map(binary_num))
    
    df.columns = df.columns.str.replace('.', ' ') 
    non_numeric_cols = df.select_dtypes(exclude=[np.number]).columns
    if len(non_numeric_cols) == 0:
        print("All columns numeric")
    else:
        print("Non-numeric columns are: ", non_numeric_cols)
    
    return df

# %%
def calculate_woe(df, feature, target):
    total_events = df[target].sum()
    total_non_events = df.shape[0] - total_events

    groups = df.groupby(feature)[target].agg(['sum', 'count'])
    groups.columns = ['events', 'non_events']

    groups['events_rate'] = groups['events'] / total_events
    groups['non_events_rate'] = groups['non_events'] / total_non_events

    groups['woe'] = np.log(groups['events_rate'] / groups['non_events_rate'])
    groups['iv'] = (groups['events_rate'] - groups['non_events_rate']) * groups['woe']
    
    woe_dict = groups['woe'].to_dict()
    iv = groups['iv'].sum()
    
    return woe_dict, iv

# %%
def encode_woe(df, cols=df.columns.tolist(), target="y"):
    df = df.copy(deep=True)
    ivs = {}
    woe_dicts = {}
    for col in cols:
        woe_dict, iv = calculate_woe(df, col, target)
        ivs[col] = iv
        woe_dicts[col] = woe_dict
        df[col] = df[col].apply(lambda x: woe_dict.get(x, 0))
        
    return df, woe_dicts, ivs

# %%
def scaling(df, scaler=StandardScaler(), fitted=False):
    if(not fitted):
        X_scaled = scaler.fit_transform(df)
    else:
        X_scaled = scaler.transform(df)
        
    df_scaled = pd.DataFrame(X_scaled, columns=df.columns, index=df.index)
    return df_scaled, scaler

# %%
df_train_e = encode_categorical(df_train)
# Out:
# Non-numeric columns are:  Index(['job', 'contact', 'poutcome'], dtype='object')
# C:\Users\Wojtek\AppData\Local\Temp\ipykernel_26556\109205136.py:32: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df.columns = df.columns.str.replace('.', ' ')

# %%
df_train_e.head()
# Out:
#    age          job  marital  education  default  balance  housing  loan  \
# 0   39  blue-collar        1          1        0      535        1     0
# 1   36  blue-collar        1         -1        0      444        0     0
# 2   50     services        1          1        0     1321        0     0
# 3   40   management        0          1        0      906        1     0
# 4   43   management        2          2        0        0        1     0
#
#     contact  day  month  duration  campaign  pdays  previous poutcome  y
# 0  cellular   20      4        89         3     -1         0  unknown  0
# 1  cellular    8      3       139         6    279         2  failure  0
# 2   unknown   17      6       271         2     -1         0  unknown  0
# 3  cellular    5      5        67         4     -1         0  unknown  0
# 4   unknown    8      5       123         2     -1         0  unknown  0

# %%
# instead of one-hot encoding to not extend dataframe
df_train_woe, woe_dicts, ivs = encode_woe(df_train_e, ["job", "poutcome", "contact"], "y")

# %%
df_train_woe.head()
# Out:
#    age       job  marital  education  default  balance  housing  loan  \
# 0   39 -0.569988        1          1        0      535        1     0
# 1   36 -0.569988        1         -1        0      444        0     0
# 2   50 -0.433691        1          1        0     1321        0     0
# 3   40 -0.000641        0          1        0      906        1     0
# 4   43 -0.000641        2          2        0        0        1     0
#
#     contact  day  month  duration  campaign  pdays  previous  poutcome  y
# 0  0.121521   20      4        89         3     -1         0 -0.377120  0
# 1  0.121521    8      3       139         6    279         2 -0.058828  0
# 2 -1.191695   17      6       271         2     -1         0 -0.377120  0
# 3  0.121521    5      5        67         4     -1         0 -0.377120  0
# 4 -1.191695    8      5       123         2     -1         0 -0.377120  0

# %%
df_train_woe_y = df_train_woe["y"]
df_train_woe_X = df_train_woe.drop("y", axis="columns")

# %%
def idx_range(df):
    index_min = df.index.min()
    index_max = df.index.max()

    print(f"Index range: {index_min} - {index_max}")

# %%
# plotting variance to analyze which columns have the most meaningful inforation
non_hot = [col for col in df_train_woe_X.columns if "_" not in col]
df_train_woe_X[non_hot].boxplot(vert=False)
plt.show()

# %%
df_train_scaled, scaler = scaling(df_train_woe_X)

# %%
df_train_scaled
# Out:
#             age       job   marital  education   default   balance   housing  \
# 0     -0.178059 -1.200994  0.270964  -0.081386 -0.135793 -0.271792  0.894408
# 1     -0.459708 -1.200994  0.270964  -2.649305 -0.135793 -0.302124 -1.118058
# 2      0.854653 -0.779362  0.270964  -0.081386 -0.135793 -0.009803 -1.118058
# 3     -0.084176  0.560274 -1.371792  -0.081386 -0.135793 -0.148130  0.894408
# 4      0.197472  0.560274  1.913719   1.202574 -0.135793 -0.450118  0.894408
# ...         ...       ...       ...        ...       ...       ...       ...
# 31642  0.009707 -1.239133  0.270964   1.202574 -0.135793  1.461802  0.894408
# 31643 -0.835240  1.202108  0.270964  -0.081386 -0.135793  3.391053  0.894408
# 31644  0.479121  0.424526 -1.371792   1.202574 -0.135793 -0.324456  0.894408
# 31645  0.479121  0.070369  1.913719   1.202574 -0.135793  1.989113 -1.118058
# 31646 -0.929122  0.070369  0.270964  -0.081386 -0.135793 -0.550780 -1.118058
#
#            loan   contact       day     month  duration  campaign     pdays  \
# 0     -0.437742  0.656533  0.510450 -0.890144 -0.656240  0.081329 -0.413799
# 1     -0.437742  0.656533 -0.934513 -1.305111 -0.460907  1.056255  2.368097
# 2     -0.437742 -1.576856  0.149209 -0.060212  0.054772 -0.243647 -0.413799
# 3     -0.437742  0.656533 -1.295754 -0.475178 -0.742187  0.406304 -0.413799
# 4     -0.437742 -1.576856 -0.934513 -0.475178 -0.523414 -0.243647 -0.413799
# ...         ...       ...       ...       ...       ...       ...       ...
# 31642  2.284449 -1.576856  0.390036 -0.060212 -0.472627 -0.243647 -0.413799
# 31643 -0.437742  0.656533  0.390036  2.014619  0.125092  0.081329 -0.413799
# 31644 -0.437742 -1.576856 -1.295754 -0.475178 -0.621080 -0.243647 -0.413799
# 31645 -0.437742 -1.576856  0.510450 -0.060212 -0.960960  0.731279 -0.413799
# 31646 -0.437742  0.656533 -0.332445  0.769721 -0.242134 -0.243647 -0.413799
#
#        previous  poutcome
# 0     -0.241021 -0.338439
# 1      0.582827  0.503698
# 2     -0.241021 -0.338439
# 3     -0.241021 -0.338439
# 4     -0.241021 -0.338439
# ...         ...       ...
# 31642 -0.241021 -0.338439
# 31643 -0.241021 -0.338439
# 31644 -0.241021 -0.338439
# 31645 -0.241021 -0.338439
# 31646 -0.241021 -0.338439
#
# [31647 rows x 16 columns]

# %% [markdown]
# ## K-means clustering method scaled data

# %%
def pca(p_df):
    # Apply PCA
    pca = PCA(n_components=0.8)   # 0.8 means 80% variance
    principalComponents = pca.fit_transform(p_df)
    df_r = pd.DataFrame(principalComponents, columns = ['principal_' + str(i) for i in range(1, pca.n_components_ + 1)])

    # Check the number of components
    print("Number of components = ", pca.n_components_)

    # Check the explained variance ratio
    print("Explained variance ratio = ", sum(pca.explained_variance_ratio_))
    
    return df_r

# %%
def count_wcss_scores(p_df, p_k):
    kmeans = KMeans(n_clusters = p_k, random_state = 0)
    kmeans.fit(p_df)
    return kmeans.score(p_df) * -1 # score returns -WCSS

# %%
def count_clustering_scores(p_df, p_cluster_num, p_model, p_score_fun):
    if isinstance(p_cluster_num, int):
        cluster_num_iter = [p_cluster_num]
    else:
        cluster_num_iter = p_cluster_num
        
    scores = []    
    for k in cluster_num_iter:
        model_instance = p_model(n_clusters = k)
        labels = model_instance.fit_predict(p_df)
        wcss = p_score_fun(p_df, labels)
        scores.append(wcss)
    
    if isinstance(p_cluster_num, int):
        return scores[0]
    else:
        return scores

# %%
def draw_elbow_wcss(p_df, p_k_max):
    cluster_num_seq = range(1, p_k_max)
    wcss_scores = []
    for k in cluster_num_seq:
        kmeans = KMeans(n_clusters = k, random_state = 0)
        kmeans.fit(p_df)
        wcss_scores.append(kmeans.score(p_df) * -1)
    plt.plot(cluster_num_seq, wcss_scores, 'bx-')
    plt.xlabel('k')
    plt.ylabel('wcss score')
    plt.title('The Elbow Method showing the optimal k')
    plt.show()

# %%
def draw_elbow_shil(p_df, p_k_max):
    cluster_num_seq = range(2, p_k_max)
    silhouette_vec = count_clustering_scores(p_df, cluster_num_seq, KMeans, silhouette_score)
    plt.plot(cluster_num_seq, silhouette_vec, 'bx-')
    plt.xlabel('k')
    plt.ylabel('Silhouette score')
    plt.title('The Elbow Method showing the optimal k')
    plt.show()

# %%
def cluster_KMeans(p_df, p_n_clusters):
    kmeans = KMeans(n_clusters = p_n_clusters, random_state = 0)

    # Fit the KMeans model to the data
    kmeans.fit(p_df)

    # Get the cluster assignments for each data point
    labels = kmeans.labels_

    # If you want to add the cluster labels back into your DataFrame
    p_df['cluster'] = labels

    print('Inertia:', kmeans.inertia_)

# %%
df_train_principal = pca(df_train_scaled)
# Out:
# Number of components =  11
# Explained variance ratio =  0.8166649795755324

# %%
#It draws elbow to select efficient number of clusters, commented since long evaluation time
draw_elbow_wcss(df_train_principal, 50)

# %%
#It runs silhouette method to visualize optimal cluster number, commented since long evaluation time
draw_elbow_shil(df_train_principal, 50)

# %%
cluster_KMeans(df_train_principal, 13)
df_train_c = df_train.copy(deep = True)
df_train_c.reset_index(inplace=True)
df_train_woe_X['cluster'] = df_train_principal['cluster']
df_train_c['cluster'] = df_train_principal['cluster']
# Out:
# Inertia: 191478.1407159591

# %%
df_train_c.head()
nan_count = df_train_c['cluster'].isna().sum()
idx_range(df_train)
print("Number of NaN clusters: ", nan_count)
# Out:
# Index range: 0 - 31646
# Number of NaN clusters:  0

# %% [markdown]
# ## K-means clustering analysys

# %%
def calculate_importance(df_X, df_y):
    rf_classifier = RandomForestClassifier()
    rf_classifier.fit(df_X, df_y)

    feature_importances = rf_classifier.feature_importances_
    feature_importances_dict = {column: importance for column, importance in zip(df_X.columns, feature_importances)}

    # Calculate the total sum of feature importances
    total_importance = sum(feature_importances)

    # Convert feature importances to percentages
    importances_percentage = [importance / total_importance * 100 for importance in feature_importances]

    # Get the column names and importances as separate lists
    column_names = list(feature_importances_dict.keys())

    # Sort the column names by importance percentage in descending order
    column_names_sorted = sorted(column_names, key=lambda x: feature_importances_dict[x], reverse=True)
    importances_percentage_sorted = [importances_percentage[column_names.index(col)] for col in column_names_sorted]

    # Create a histogram
    plt.figure(figsize=(10, 6))
    plt.bar(column_names_sorted, importances_percentage_sorted)
    plt.xlabel('Column Name')
    plt.ylabel('Importance (%)')
    plt.title('Feature Importances')

    # Add the numeric values on top of each column
    for i in range(len(column_names_sorted)):
        plt.text(i, importances_percentage_sorted[i], f'{importances_percentage_sorted[i]:.2f}', ha='center', va='bottom')

    # Rotate x-axis labels for better readability
    plt.xticks(rotation=90)

    # Show the plot
    plt.show()

# %%
# showing feature importance for random forest model to visualize data
calculate_importance(df_train_woe_X, df_train_woe_y)

# %%
fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')

sc = ax.scatter(df_train_c['balance'], df_train_c['age'], df_train_c['duration'],   c=df_train_c['cluster'], alpha=0.6, edgecolors='w', s=80)

ax.set_xlabel('Balance')
ax.set_ylabel('Age')
ax.set_zlabel('Duration')

plt.colorbar(sc, label='cluster')  # Show color scale
plt.title('3D scatter plot of Age, Duration, and Balance')
plt.show()

# %%
df_train_means = df_train_c.groupby('cluster')[['balance', 'age', 'duration']].median()
fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')

# Get cluster labels and use as colors
clusters = df_train_means.index
colors = plt.cm.rainbow(np.linspace(0, 1, len(clusters)))

for cluster, color in zip(clusters, colors):
    ax.scatter(df_train_means.loc[cluster, 'balance'], df_train_means.loc[cluster, 'age'], df_train_means.loc[cluster, 'duration'], color=color, alpha=0.6, edgecolors='w', s=80, label='Cluster {}'.format(cluster))
    ax.text(df_train_means.loc[cluster, 'balance'], df_train_means.loc[cluster, 'age'], df_train_means.loc[cluster, 'duration'], '%s' % (str(cluster)), size=10, zorder=1, color='k')

ax.set_xlabel('Median Balance')
ax.set_ylabel('Median Age')
ax.set_zlabel('Median Duration')

plt.legend()
plt.title('3D scatter plot of median Age, Duration, and Balance per cluster')
plt.show()

# %%
# Get the most common jobs for each cluster
top_jobs = df_train_c.groupby('cluster')['job'].apply(lambda x: x.value_counts().nlargest(3))

# Convert the multi-index series to a dataframe
top_jobs_df = top_jobs.reset_index()

# Rename columns
top_jobs_df.columns = ['cluster', 'job', 'count']

# View the DataFrame
top_jobs_df.head()
# Out:
#    cluster          job  count
# 0        0   management    173
# 1        0   technician     63
# 2        0  blue-collar     46
# 3        1  blue-collar   1272
# 4        1     services    623

# %%
# Define the colors for each cluster
colors = ['blue', 'orange', 'green', 'red', 'purple', 'brown', 'pink', 'gray', 'olive', 'cyan', 'magenta', 'lime', 'teal']
cluster_colors = {i: colors[i] for i in range(len(colors))}

# %%
# Get unique jobs and clusters
unique_jobs = top_jobs_df['job'].unique()
unique_clusters = top_jobs_df['cluster'].unique()

# Set up the figure and axis
fig, ax = plt.subplots(figsize=(12, 8))

# Create a bar for each job
for idx, job in enumerate(unique_jobs):
    # Get the counts for each cluster for the current job
    counts = top_jobs_df[top_jobs_df['job'] == job]['count']
    clusters = top_jobs_df[top_jobs_df['job'] == job]['cluster']

    # Create a bar for each cluster
    for cluster_idx, count in enumerate(counts):
        # If this is the first cluster, create the base of the bar
        if cluster_idx == 0:
            bar = ax.bar(idx, count, color=cluster_colors[clusters.iloc[cluster_idx]])
        # If this is not the first cluster, add to the existing bar
        else:
            bar = ax.bar(idx, count, bottom=counts.iloc[:cluster_idx].sum(), color=cluster_colors[clusters.iloc[cluster_idx]])

        # Add the cluster number to the bar segment
        height = counts.iloc[:cluster_idx+1].sum()
        ax.text(idx, height - count/2, f'CL:{clusters.iloc[cluster_idx]}', ha='center', va='center', color='white')

# Set up the x-axis
ax.set_xticks(range(len(unique_jobs)))
ax.set_xticklabels(unique_jobs, rotation=90)

# Add labels and title
ax.set_ylabel('Count')
ax.set_xlabel('Job')
ax.set_title('Cluster distribution for each job')

plt.show()

# %%
# Define the age intervals and labels for the buckets
age_intervals = range(18, 70, 5)
age_labels = [f'{start}-{start+4}' for start in age_intervals[:-1]]  # Remove the last interval

# Group the data by age and cluster and calculate the counts
df_train_c['age_bucket'] = pd.cut(df_train_c['age'], bins=age_intervals, labels=age_labels)
grouped_data = df_train_c.groupby(['age_bucket', 'cluster']).size().reset_index(name='count')

# Get unique age buckets and clusters
unique_age_buckets = grouped_data['age_bucket'].unique()
unique_clusters = grouped_data['cluster'].unique()

# Set up the figure and axis
fig, ax = plt.subplots(figsize=(12, 8))

# Create a bar for each age bucket
for idx, age_bucket in enumerate(unique_age_buckets):
    # Get the counts for each cluster for the current age bucket
    counts = grouped_data[grouped_data['age_bucket'] == age_bucket]['count']
    clusters = grouped_data[grouped_data['age_bucket'] == age_bucket]['cluster']

    # Create a bar for each cluster
    for cluster_idx, count in enumerate(counts):
        # If this is the first cluster, create the base of the bar
        if cluster_idx == 0:
            bar = ax.bar(idx, count, color=cluster_colors[clusters.iloc[cluster_idx]])
        # If this is not the first cluster, add to the existing bar
        else:
            bar = ax.bar(idx, count, bottom=counts.iloc[:cluster_idx].sum(), color=cluster_colors[clusters.iloc[cluster_idx]])

        # Add the cluster number to the bar segment
        height = counts.iloc[:cluster_idx+1].sum()
        ax.text(idx, height - count/2, f'CL:{clusters.iloc[cluster_idx]}', ha='center', va='center', color='white')

# Set up the x-axis
ax.set_xticks(range(len(unique_age_buckets)))
ax.set_xticklabels(unique_age_buckets, rotation=90)

# Add labels and title
ax.set_ylabel('Count')
ax.set_xlabel('Age Bucket')
ax.set_title('Cluster distribution for each age bucket')

plt.show()

# %%
cluster_details = {
    0: "old_low_balance_retired",
    1: "housemaid",
    2: "middle_low_balance",
    3: "young_low_balance",
    4: "admin_management",
    5: "long_duration",
    6: 6,
    7: 7,
    8: "students",
    9: 8,
    10: 10,
    11:"high_balance",
    12: 12,
}

# %%
df_train_c = df_train_c[['cluster']]  # Select 'cluster' column from df_train_c

merged_df = df_train_woe_y.to_frame().merge(df_train_c, left_index=True, right_index=True)
cluster_perc = pd.DataFrame(merged_df.groupby('cluster')['y'].mean()).reset_index()
cluster_perc = cluster_perc.rename(columns={"y":"yes"})
cluster_perc["no"] = 1 - cluster_perc["yes"]
cluster_perc["cluster"] = cluster_perc["cluster"].map(cluster_details)
cluster_perc
# Out:
#                     cluster       yes        no
# 0   old_low_balance_retired  0.123077  0.876923
# 1                 housemaid  0.037217  0.962783
# 2        middle_low_balance  0.063952  0.936048
# 3         young_low_balance  0.560142  0.439858
# 4          admin_management  0.041254  0.958746
# 5             long_duration  0.170471  0.829529
# 6                         6  0.097853  0.902147
# 7                         7  0.535685  0.464315
# 8                  students  0.031873  0.968127
# 9                         8  0.061189  0.938811
# 10                       10  0.042186  0.957814
# 11             high_balance  0.058093  0.941907
# 12                       12  0.165177  0.834823

# %%
# Convert 'cluster' column to string
cluster_perc['cluster'] = cluster_perc['cluster'].astype(str)

# Plotting the DataFrame
plt.figure(figsize=(8, 6))

# Calculate the position of each cluster
position = np.arange(len(cluster_perc))

# Width of each cluster column
width = 0.5

# Plotting the 'yes' and 'no' columns as separate sets of bars
plt.bar(position, cluster_perc['yes'], width, color='green', label='Yes')
plt.bar(position, cluster_perc['no'], width, color='red', bottom=cluster_perc['yes'], label='No')

# X-axis ticks and labels
plt.xticks(position, cluster_perc['cluster'], rotation=90)

# Y-axis labels and limits
plt.ylabel('Percentage')
plt.ylim(0, 1)

# Title and legend
plt.title('Percentage of Yes and No by Cluster')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Clustering Evaluation

# %%
df_test_e = encode_categorical(df_test)
df_test_woe, woe_dicts, ivs = encode_woe(df_test_e, ["job", "poutcome", "contact"], "y")
df_test_woe_y = df_test_woe["y"]
df_test_woe_X = df_test_woe.drop("y", axis="columns")
df_test_scaled, scaler = scaling(df_test_woe_X, scaler=scaler, fitted=True)
df_test_principal = pca(df_test_scaled)
cluster_KMeans(df_test_principal, 13)
df_test_c = df_test.copy(deep = True)
df_test_woe_X['cluster'] = df_test_principal['cluster']
df_test_c['cluster'] = df_test_principal['cluster']
nan_count = df_test_c['cluster'].isna().sum()
idx_range(df_test)
print("Number of NaN clusters: ", nan_count)
# Out:
# C:\Users\Wojtek\AppData\Local\Temp\ipykernel_26556\109205136.py:32: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df.columns = df.columns.str.replace('.', ' ')
# Non-numeric columns are:  Index(['job', 'contact', 'poutcome'], dtype='object')
# Number of components =  11
# Explained variance ratio =  0.835850040150264
# Inertia: 83577.33889934831
# Index range: 0 - 13563
# Number of NaN clusters:  0

# %%
df_test_woe_X.head()
df_test_woe_X.shape
# Out:
# (13564, 17)

# %%
df_train_woe_X.head()
df_train_woe_X.shape
# Out:
# (31647, 17)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

merged_test_data = pd.concat([df_test_woe_X, df_test_woe_y], axis=1)
merged_train_data = pd.concat([df_train_woe_X, df_train_woe_y], axis=1)
# List to store accuracy for each cluster
accuracy_list = []

# Iterate over each cluster
for cluster in range(13):
    # Split train and test data based on the cluster
    train_data_cluster = merged_train_data[merged_train_data['cluster'] == cluster]
    test_data_cluster = merged_test_data[merged_test_data['cluster'] == cluster]
    
    # Separate features and labels for train and test data
    X_train = train_data_cluster.drop('y', axis=1)
    y_train = train_data_cluster['y']
    X_test = test_data_cluster.drop('y', axis=1)
    y_test = test_data_cluster['y']
    
    # Fit a model on the train data
    model = LogisticRegression()
    model.fit(X_train, y_train)
    
    # Predict labels for the test data
    y_pred = model.predict(X_test)
    
    # Calculate accuracy for the current cluster
    accuracy = accuracy_score(y_test, y_pred)
    
    # Store accuracy in the list
    accuracy_list.append(accuracy)

# Calculate mean accuracy across all clusters
mean_accuracy = np.mean(accuracy_list)
# Out:
# C:\Users\Wojtek\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Wojtek\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Wojtek\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Wojtek\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Wojtek\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Wojtek\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Wojtek\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Wojtek\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Wojtek\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Wojtek\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Wojtek\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Wojtek\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Wojtek\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
print(mean_accuracy)
print(accuracy_list)
# Out:
# 0.7964341270816147
# [0.8416206261510129, 0.9664536741214057, 0.8522039757994814, 0.1540864133263925, 0.9720024345709068, 0.9256198347107438, 0.8551372048500319, 0.5834797891036907, 0.43447037701974867, 0.9520671060515279, 0.9790419161676647, 0.9659006671608599, 0.8715596330275229]

# %%
X_train = train_data_cluster.drop('y', axis=1)
y_train = train_data_cluster['y']
X_test = test_data_cluster.drop('y', axis=1)
y_test = test_data_cluster['y']


# Fit a model on the train data
model = LogisticRegression()
model.fit(X_train, y_train)

# Predict labels for the test data
y_pred = model.predict(X_test)

# Calculate accuracy for the current cluster
accuracy_alone = accuracy_score(y_test, y_pred)
accuracy_alone
# Out:
# C:\Users\Wojtek\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.8715596330275229

# %% [markdown]
# ## hierarchy clustering

# %%
# my computer cannot operate on so many rows
df_t_r, _ = train_test_split(df_train, train_size=0.1, shuffle=True)

# %%
df_t_r.head()
# Out:
#        age           job   marital  education default  balance housing loan  \
# 30273   32      services    single  secondary      no       48     yes  yes
# 11885   36  entrepreneur   married   tertiary      no      280     yes   no
# 5540    31      services   married    unknown      no      -82     yes   no
# 15373   39    management  divorced   tertiary      no     9541      no   no
# 28656   56  entrepreneur  divorced  secondary      no      179      no   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome   y
# 30273  cellular   18   nov       132         1     -1         0  unknown  no
# 11885  cellular    7   may       252         1    351         1  failure  no
# 5540   cellular   31   jul       543        31     -1         0  unknown  no
# 15373   unknown   15   may       815         1     -1         0  unknown  no
# 28656  cellular   14   aug        47         2     -1         0  unknown  no

# %%
df_t_r.shape
# Out:
# (3164, 17)

# %%
df_t_r_e = encode_categorical(df_t_r)
# Out:
# Non-numeric columns are:  Index(['job', 'contact', 'poutcome'], dtype='object')
# C:\Users\Wojtek\AppData\Local\Temp\ipykernel_26556\109205136.py:32: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df.columns = df.columns.str.replace('.', ' ')

# %%
df_t_r_e.head()
# Out:
#        age           job  marital  education  default  balance  housing  loan  \
# 30273   32      services        0          1        0       48        1     1
# 11885   36  entrepreneur        1          2        0      280        1     0
# 5540    31      services        1         -1        0      -82        1     0
# 15373   39    management        2          2        0     9541        0     0
# 28656   56  entrepreneur        2          1        0      179        0     0
#
#         contact  day  month  duration  campaign  pdays  previous poutcome  y
# 30273  cellular   18     11       132         1     -1         0  unknown  0
# 11885  cellular    7      5       252         1    351         1  failure  0
# 5540   cellular   31      7       543        31     -1         0  unknown  0
# 15373   unknown   15      5       815         1     -1         0  unknown  0
# 28656  cellular   14      8        47         2     -1         0  unknown  0

# %%
df_t_r_woe, woe_reduced_dicts, reduced_ivs = encode_woe(df_t_r_e, ["job", "poutcome", "contact"], "y")

# %%
df_t_r_woe.head()
# Out:
#        age       job  marital  education  default  balance  housing  loan  \
# 30273   32 -0.533049        0          1        0       48        1     1
# 11885   36 -0.710582        1          2        0      280        1     0
# 5540    31 -0.533049        1         -1        0      -82        1     0
# 15373   39  0.046910        2          2        0     9541        0     0
# 28656   56 -0.710582        2          1        0      179        0     0
#
#         contact  day  month  duration  campaign  pdays  previous  poutcome  y
# 30273  0.155431   18     11       132         1     -1         0 -0.387244  0
# 11885  0.155431    7      5       252         1    351         1 -0.056656  0
# 5540   0.155431   31      7       543        31     -1         0 -0.387244  0
# 15373 -1.189097   15      5       815         1     -1         0 -0.387244  0
# 28656  0.155431   14      8        47         2     -1         0 -0.387244  0

# %%
df_t_r_s, scaler = scaling(df_t_r_woe)

# %%
df_t_r_s.head()
# Out:
#             age       job   marital  education   default   balance   housing  \
# 30273 -0.833951 -0.875664 -1.374817  -0.036784 -0.124114 -0.477614  0.898888
# 11885 -0.459692 -1.340285  0.275381   1.214667 -0.124114 -0.383544  0.898888
# 5540  -0.927516 -0.875664  0.275381  -2.539686 -0.124114 -0.530325  0.898888
# 15373 -0.178997  0.642145  1.925578   1.214667 -0.124114  3.371555 -1.112485
# 28656  1.411605 -1.340285  1.925578  -0.036784 -0.124114 -0.424497 -1.112485
#
#            loan   contact       day     month  duration  campaign     pdays  \
# 30273  2.234373  0.715412  0.240661  2.048384 -0.475369 -0.568352 -0.421161
# 11885 -0.447553  0.715412 -1.076523 -0.476387 -0.009143 -0.568352  2.972261
# 5540  -0.447553  0.715412  1.797333  0.365203  1.121455  9.249288 -0.421161
# 15373 -0.447553 -1.501023 -0.118571 -0.476387  2.178234 -0.568352 -0.421161
# 28656 -0.447553  0.715412 -0.238315  0.785999 -0.805613 -0.241097 -0.421161
#
#        previous  poutcome         y
# 30273 -0.324638 -0.350534 -0.368345
# 11885  0.232388  0.511439 -0.368345
# 5540  -0.324638 -0.350534 -0.368345
# 15373 -0.324638 -0.350534 -0.368345
# 28656 -0.324638 -0.350534 -0.368345

# %%
df_t_r_pca = pca(df_t_r_s)
# Out:
# Number of components =  11
# Explained variance ratio =  0.8074038439342837

# %%
df_t_r_pca.head()
# Out:
#    principal_1  principal_2  principal_3  principal_4  principal_5  \
# 0    -0.818289     0.438129    -1.526799    -0.652087     1.601820
# 1     1.860956     2.171476    -0.205785    -0.146519    -0.472802
# 2    -2.109291    -0.405231    -0.557662    -2.178715     4.998717
# 3    -0.280295    -1.634738     1.073416     1.508668    -1.835507
# 4    -0.551657    -0.991190     2.047848    -0.902603     0.106809
#
#    principal_6  principal_7  principal_8  principal_9  principal_10  \
# 0    -1.012217     1.865804    -0.688463    -1.189355      0.018226
# 1    -0.477105     0.432260    -0.304193    -0.622837     -1.177828
# 2     5.598395    -2.298837     0.615698    -0.678829      1.528027
# 3     0.292594     0.862110    -2.237200     1.562205      0.715230
# 4    -0.395019     0.536022     0.542037    -1.037716     -1.085380
#
#    principal_11
# 0     -0.952626
# 1      1.024246
# 2      4.797983
# 3      0.624543
# 4      0.197812

# %%
def c_dendrogram(p_df, p_method):
    mergings = linkage(p_df, method=p_method)
    dendrogram(mergings, leaf_rotation=90, leaf_font_size=2)
    plt.show()
    
    return mergings

# %%
def c_labels(p_mergings, p_fcluster_level):
    return fcluster(p_mergings, p_fcluster_level, criterion='distance')

# %%
def c_tsne(p_df, columns):
    for columns in columns:
        print(f"COLUMN '{columns}'")
        model_2d = TSNE(learning_rate=200)
        transformed = model_2d.fit_transform(p_df)
        xs = transformed[:, 0]
        ys = transformed[:, 1]
        plt.scatter(xs, ys, c=p_df[columns])
        plt.show()

        model_3d = TSNE(n_components=3, learning_rate=200)
        transformed = model_3d.fit_transform(p_df)
        xs = transformed[:, 0]
        ys = transformed[:, 1]
        zs = transformed[:, 2]
        fig = plt.figure()
        ax = fig.add_subplot(projection='3d')
        sc = ax.scatter(xs, ys, zs, c=p_df[columns], alpha=0.6, edgecolors='w')
        plt.colorbar(sc, label='cluster')
        plt.show()
        print()

# %%
x = {}

# %%
merg_complete = c_dendrogram(df_t_r_pca, 'complete')

# %%
df_t_r_s["labels_complete"] = c_labels(merg_complete, 10.5)

# %%
merg_single = c_dendrogram(df_t_r_pca, 'single')

# %%
df_t_r_s["labels_single"] = c_labels(merg_single, 5.5)

# %%
merg_average = c_dendrogram(df_t_r_pca, 'average')

# %%
df_t_r_s["labels_average"] = c_labels(merg_average, 7.75)

# %%
merg_weighted = c_dendrogram(df_t_r_pca, 'weighted')

# %%
df_t_r_s["labels_weighted"] = c_labels(merg_weighted, 8)

# %%
merg_centroid = c_dendrogram(df_t_r_pca, 'centroid')

# %%
df_t_r_s["labels_centroid"] = c_labels(merg_centroid, 6)

# %%
merg_median = c_dendrogram(df_t_r_pca, 'median')

# %%
df_t_r_s["labels_median"] = c_labels(merg_median, 6)

# %%
merg_ward = c_dendrogram(df_t_r_pca, 'ward')

# %%
df_t_r_s["labels_ward"] = c_labels(merg_ward, 15)

# %%
c_tsne(df_t_r_s, ["labels_complete",
                   "labels_single",
                   "labels_average",
                   "labels_weighted",
                   "labels_centroid",
                   "labels_median", 
                   "labels_ward"])
# Out:
# COLUMN 'labels_complete'
# C:\Users\Wojtek\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\Wojtek\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# COLUMN 'labels_single'
# C:\Users\Wojtek\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\Wojtek\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# COLUMN 'labels_average'
# C:\Users\Wojtek\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\Wojtek\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# COLUMN 'labels_weighted'
# C:\Users\Wojtek\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\Wojtek\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# COLUMN 'labels_centroid'
# C:\Users\Wojtek\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\Wojtek\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# COLUMN 'labels_median'
# C:\Users\Wojtek\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\Wojtek\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# COLUMN 'labels_ward'
# C:\Users\Wojtek\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\Wojtek\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(

# %%
labels = [column for column in df_t_r_s.columns if column.startswith("labels_")]

# %%
for label in labels:
    print(f'in "{label}" column are {len(df_t_r_s[label].unique())} clusters')
# Out:
# in "labels_complete" column are 8 clusters
# in "labels_single" column are 2 clusters
# in "labels_average" column are 5 clusters
# in "labels_weighted" column are 7 clusters
# in "labels_centroid" column are 8 clusters
# in "labels_median" column are 9 clusters
# in "labels_ward" column are 41 clusters
