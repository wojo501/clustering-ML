# %% [markdown]
# ## Importing

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

# %%
df = pd.read_csv("./data/bank-full.csv")
df.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  unknown    5   may       261         1     -1         0  unknown  no
# 1  unknown    5   may       151         1     -1         0  unknown  no
# 2  unknown    5   may        76         1     -1         0  unknown  no
# 3  unknown    5   may        92         1     -1         0  unknown  no
# 4  unknown    5   may       198         1     -1         0  unknown  no

# %%
has_null = df.isnull().any().any()
has_null
# Out:
# False

# %% [markdown]
# ## Spliting Data ?

# %% [markdown]
# ## Transformers

# %%
def encode_categorical(df_orginal):
    df = df_orginal.copy(deep=True)
    
    months = ['jan', 'feb',
       'mar', 'apr', 'may', 'jun', 'jul', 'aug', 'sep', 'oct', 'nov', 'dec']
    month_num = {months[i]: i+1 for i in range(len(months))}
    df["month"] = df["month"].map(month_num)
    
    edu_num = {'tertiary':2, 'secondary':1, 'unknown':-1, 'primary':0}
    df["education"] = df["education"].map(edu_num)
    
    marital_num = {'single':0, 'married':1, 'divorced':2}
    df["marital"] = df["marital"].map(marital_num)
    
    # Encoding for binary columns
    binary_num = {"no":0 ,"yes":1}
    binaries = [col for col in df.columns if set(df[col].unique()) == {"yes", "no"}]
    df[binaries] = df[binaries].apply(lambda x: x.map(binary_num))
    
    # One Hot Encoding for specified columns
    for column in ['contact', 'job', 'poutcome']:
        df = df.join(pd.get_dummies(df[column], prefix=column))
        del df[column]
        
    df.columns = df.columns.str.replace('.', ' ')
    
    non_numeric_cols = df.select_dtypes(exclude=[np.number]).columns
    if len(non_numeric_cols) == 0:
        print("All columns numeric")
    else:
        print("Non-numeric columns are: ", non_numeric_cols)
    
    return df

# %%
def scaling(df, scaler=StandardScaler()):
    X_scaled = scaler.fit_transform(df)
    df_scaled = pd.DataFrame(X_scaled, columns=df.columns)
    return df_scaled

# %%
df = encode_categorical(df)
# Out:
# All columns numeric
# C:\Users\Wojtek\AppData\Local\Temp\ipykernel_14076\601411229.py:25: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df.columns = df.columns.str.replace('.', ' ')

# %%
y_df = df["y"]
X_df = df.drop(['y'], axis=1)

# %%
X_df.describe()
# Out:
#                 age       marital     education       default        balance  \
# count  45211.000000  45211.000000  45211.000000  45211.000000   45211.000000
# mean      40.936210      0.832275      1.060516      0.018027    1362.272058
# std       10.618762      0.608230      0.778704      0.133049    3044.765829
# min       18.000000      0.000000     -1.000000      0.000000   -8019.000000
# 25%       33.000000      0.000000      1.000000      0.000000      72.000000
# 50%       39.000000      1.000000      1.000000      0.000000     448.000000
# 75%       48.000000      1.000000      2.000000      0.000000    1428.000000
# max       95.000000      2.000000      2.000000      1.000000  102127.000000
#
#             housing          loan           day         month      duration  \
# count  45211.000000  45211.000000  45211.000000  45211.000000  45211.000000
# mean       0.555838      0.160226     15.806419      6.144655    258.163080
# std        0.496878      0.366820      8.322476      2.408034    257.527812
# min        0.000000      0.000000      1.000000      1.000000      0.000000
# 25%        0.000000      0.000000      8.000000      5.000000    103.000000
# 50%        1.000000      0.000000     16.000000      6.000000    180.000000
# 75%        1.000000      0.000000     21.000000      8.000000    319.000000
# max        1.000000      1.000000     31.000000     12.000000   4918.000000
#
#        ...  job_self-employed  job_services   job_student  job_technician  \
# count  ...       45211.000000   45211.00000  45211.000000    45211.000000
# mean   ...           0.034925       0.09188      0.020747        0.168034
# std    ...           0.183592       0.28886      0.142538        0.373901
# min    ...           0.000000       0.00000      0.000000        0.000000
# 25%    ...           0.000000       0.00000      0.000000        0.000000
# 50%    ...           0.000000       0.00000      0.000000        0.000000
# 75%    ...           0.000000       0.00000      0.000000        0.000000
# max    ...           1.000000       1.00000      1.000000        1.000000
#
#        job_unemployed   job_unknown  poutcome_failure  poutcome_other  \
# count    45211.000000  45211.000000      45211.000000    45211.000000
# mean         0.028820      0.006370          0.108403        0.040698
# std          0.167303      0.079559          0.310892        0.197592
# min          0.000000      0.000000          0.000000        0.000000
# 25%          0.000000      0.000000          0.000000        0.000000
# 50%          0.000000      0.000000          0.000000        0.000000
# 75%          0.000000      0.000000          0.000000        0.000000
# max          1.000000      1.000000          1.000000        1.000000
#
#        poutcome_success  poutcome_unknown
# count      45211.000000      45211.000000
# mean           0.033421          0.817478
# std            0.179735          0.386278
# min            0.000000          0.000000
# 25%            0.000000          1.000000
# 50%            0.000000          1.000000
# 75%            0.000000          1.000000
# max            1.000000          1.000000
#
# [8 rows x 32 columns]

# %%
non_hot = [col for col in X_df.columns if "_" not in col]
X_df[non_hot].boxplot(vert=False)
plt.show()

# %%
df_scaled = scaling(df)

# %% [markdown]
# ## K-means clustering method fully scaled data

# %%
def count_wcss_scores(X, k_max):
    #  WCSS = within-cluster sum of squares
    scores = []
    for k in range(1, k_max+1):
        kmeans = KMeans(n_clusters=k, random_state=0)
        kmeans.fit(X)
        wcss = kmeans.score(X) * -1 # score returns -WCSS
        scores.append(wcss)
    return scores

# %%
def draw_elbow(df, k_max):
    wcss_vec = count_wcss_scores(df, 100)
    x_ticks = list(range(1, len(wcss_vec) + 1))
    plt.plot(x_ticks, wcss_vec, 'bx-')
    plt.xlabel('k')
    plt.ylabel('Within-cluster sum of squares')
    plt.title('The Elbow Method showing the optimal k')
    plt.show()

# %%
draw_elbow(df_scaled, 100)

# %%
kmeans = KMeans(n_clusters=25, random_state=0)

# Fit the KMeans model to the data
kmeans.fit(df_scaled)

# Get the cluster assignments for each data point
labels = kmeans.labels_

# If you want to add the cluster labels back into your DataFrame
df_scaled['cluster'] = labels

df_scaled.head()
# Out:
#         age   marital  education  default   balance   housing      loan  \
# 0  1.606965  0.275762   1.206484 -0.13549  0.256419  0.893915 -0.436803
# 1  0.288529 -1.368372  -0.077715 -0.13549 -0.437895  0.893915 -0.436803
# 2 -0.747384  0.275762  -0.077715 -0.13549 -0.446762  0.893915  2.289359
# 3  0.571051  0.275762  -2.646114 -0.13549  0.047205  0.893915 -0.436803
# 4 -0.747384 -1.368372  -2.646114 -0.13549 -0.447091 -1.118674 -0.436803
#
#         day     month  duration  ...  job_services  job_student  \
# 0 -1.298476 -0.475354  0.011016  ...     -0.318082    -0.145557
# 1 -1.298476 -0.475354 -0.416127  ...     -0.318082    -0.145557
# 2 -1.298476 -0.475354 -0.707361  ...     -0.318082    -0.145557
# 3 -1.298476 -0.475354 -0.645231  ...     -0.318082    -0.145557
# 4 -1.298476 -0.475354 -0.233620  ...     -0.318082    -0.145557
#
#    job_technician  job_unemployed  job_unknown  poutcome_failure  \
# 0       -0.449414       -0.172266    -0.080069         -0.348687
# 1        2.225121       -0.172266    -0.080069         -0.348687
# 2       -0.449414       -0.172266    -0.080069         -0.348687
# 3       -0.449414       -0.172266    -0.080069         -0.348687
# 4       -0.449414       -0.172266    12.489301         -0.348687
#
#    poutcome_other  poutcome_success  poutcome_unknown  cluster
# 0       -0.205972         -0.185948          0.472519        8
# 1       -0.205972         -0.185948          0.472519        1
# 2       -0.205972         -0.185948          0.472519       13
# 3       -0.205972         -0.185948          0.472519        2
# 4       -0.205972         -0.185948          0.472519       11
#
# [5 rows x 34 columns]

# %%
print('Inertia:', kmeans.inertia_)
# Out:
# Inertia: 597501.8828347288
